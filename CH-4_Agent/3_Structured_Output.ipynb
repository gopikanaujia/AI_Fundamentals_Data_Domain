# %%
from langchain_openai import OpenAI
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv()
llm = ChatOpenAI(model="gpt-5-mini")

# %%
response = llm.invoke("What is the capital of France? Generate the the output with this format:: " 'Query: <the query>' "'Answer: <the answer>'")
response = response.content
print(response)
# Out:
# Query: What is the capital of France?'Answer: Paris'

# %%
from pydantic import BaseModel, Field

class llm_schema(BaseModel):
    query: str = Field(description="The quesry that was asked to the LLM")
    answer: str = Field(description="The answer that the LLM generated")
    total_tokens: int = Field(description="The total number of tokens used in the LLM response")

# %%
# obj = llm_schema(quesry="What is the capital of France?", answer="The capital of Francef is Paris.", total_tokens=10)
# obj
# Out:
# llm_schema(quesry='What is the capital of France?', answer='The capital of Francef is Paris.', total_tokens=10)

# %%
llm_structured = llm.with_structured_output(llm_schema)
response =llm_structured.invoke("What is the capital of France?")
print(response)
# Out:
# query='What is the capital of France?' answer='Paris' total_tokens=12

# %%
response.model_dump_json()
# Out:
# '{"query":"What is the capital of France?","answer":"Paris","total_tokens":12}'

# %%
response.model_dump()
# Out:
# {'query': 'What is the capital of France?',
#  'answer': 'Paris',
#  'total_tokens': 12}

# %%
response.model_dump()['query']
# Out:
# 'What is the capital of France?'
