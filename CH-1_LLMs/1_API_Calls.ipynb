# %%
from dotenv import load_dotenv
load_dotenv()
import os

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI_API_KEY is set.")
if os.environ.get("GEMINI_API_KEY"):
    print("GEMINI_API_KEY is set.")
# Out:
# OPENAI_API_KEY is set.
# GEMINI_API_KEY is set.

# %%
# OPENAI SDK

# %%
from openai import OpenAI

client = OpenAI()

response = client.responses.create(
    model="gpt-5-mini",
    input="Tell me a fun fact about Data Domain"
)

print(response.output_text)
# Out:
# Fun fact: Data Domain appliances were among the first commercial systems to use inline, variable‑length deduplication for backup data—so after the initial backup, most subsequent backups send only new unique data, dramatically cutting network traffic and storage needs. EMC liked it enough to acquire Data Domain in 2009 for about $2.4 billion.

# %%
 # GEMINI SDK

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", 
    contents="Tell me a fun fact about Data Domain"
)
print(response.text)
# Out:
# Here's a fun fact about Data Domain:
#
# They were pioneers in perfecting **"inline deduplication"**.
#
# What this means is that a Data Domain appliance could intelligently analyze and remove redundant data *as it was being received*, before it even hit the disk. Most earlier deduplication methods were "post-process" (data wrote to disk, *then* was de-duped).
#
# This "inline" approach allowed Data Domain to achieve unprecedented storage reduction ratios (often 10x, 20x, or even 50x for typical backup data!) *and* optimize network bandwidth simultaneously. It's one of the key reasons they revolutionized backup storage and largely replaced tape as the primary backup target in many data centers worldwide.
